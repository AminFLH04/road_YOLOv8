# %% [markdown]
# <a href="https://colab.research.google.com/github/AminFLH04/road_YOLOv8/blob/main/yolo_v8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # INSTALLATION

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
import os
# %cd /content/ultralytics/
# !pip install -r requirements.txt
# !pip install ultralytics
# %cd /content/
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 15648, done.
# remote: Counting objects: 100% (281/281), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 15648 (delta 147), reused 217 (delta 106), pack-reused 15367
# Receiving objects: 100% (15648/15648), 8.45 MiB | 14.79 MiB/s, done.
# Resolving deltas: 100% (10791/10791), done.
# /content/ultralytics
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 614.2/614.2 kB 7.6 MB/s eta 0:00:00
# ...
# /content

# %% [markdown]
# #DETECT

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/input.mp4"
# Out:
# Ultralytics YOLOv8.0.171 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# video 1/1 (1/323) /content/input.mp4: 384x640 5 cars, 2 trucks, 102.2ms
# video 1/1 (2/323) /content/input.mp4: 384x640 5 cars, 2 trucks, 6.7ms
# video 1/1 (3/323) /content/input.mp4: 384x640 6 cars, 2 trucks, 7.4ms
# video 1/1 (4/323) /content/input.mp4: 384x640 6 cars, 3 trucks, 6.7ms
# video 1/1 (5/323) /content/input.mp4: 384x640 6 cars, 1 truck, 6.8ms
# video 1/1 (6/323) /content/input.mp4: 384x640 7 cars, 1 truck, 7.2ms
# video 1/1 (7/323) /content/input.mp4: 384x640 6 cars, 1 truck, 6.6ms
# video 1/1 (8/323) /content/input.mp4: 384x640 5 cars, 1 truck, 6.5ms
# video 1/1 (9/323) /content/input.mp4: 384x640 6 cars, 1 truck, 8.4ms
# video 1/1 (10/323) /content/input.mp4: 384x640 6 cars, 1 truck, 6.7ms
# video 1/1 (11/323) /content/input.mp4: 384x640 6 cars, 1 truck, 6.8ms
# ...

# %%
# save_path is the path to result of previous cell
save_path = "/content/runs/detect/predict11/input.avi"
result_path = "/content/result.mp4"
os.system(f'ffmpeg -i {save_path} -vcodec libx264 {result_path}')
# Out:
# 0

# %% [markdown]
# # SEGMENT

# %%
# !yolo task=segment mode=predict model=yolov8n-seg.pt conf=0.25 source="/content/input.mp4"
# Out:
# ...
# 100% 6.73M/6.73M [00:00<00:00, 57.3MB/s]
# Ultralytics YOLOv8.0.171 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n-seg summary (fused): 195 layers, 3404320 parameters, 0 gradients
#
# video 1/1 (1/323) /content/input.mp4: 384x640 1 person, 5 cars, 4 trucks, 229.3ms
# video 1/1 (2/323) /content/input.mp4: 384x640 1 person, 5 cars, 1 truck, 8.1ms
# video 1/1 (3/323) /content/input.mp4: 384x640 6 cars, 2 trucks, 8.7ms
# video 1/1 (4/323) /content/input.mp4: 384x640 7 cars, 2 trucks, 8.0ms
# video 1/1 (5/323) /content/input.mp4: 384x640 7 cars, 1 truck, 8.2ms
# video 1/1 (6/323) /content/input.mp4: 384x640 5 cars, 3 trucks, 8.7ms
# video 1/1 (7/323) /content/input.mp4: 384x640 6 cars, 2 trucks, 8.0ms
# video 1/1 (8/323) /content/input.mp4: 384x640 1 person, 5 cars, 2 trucks, 8.3ms
# video 1/1 (9/323) /content/input.mp4: 384x640 1 person, 4 cars, 2 trucks, 9.1ms
# video 1/1 (10/323) /content/input.mp4: 384x640 1 person, 4 cars, 1 truck, 8.1ms
# ...

# %%
# save_path is the path to result of previous cell
save_path = "/content/runs/segment/predict/input.avi"
result_path = "/content/result.mp4"
os.system(f'ffmpeg -i {save_path} -vcodec libx264 {result_path}')
# Out:
# 0

# %% [markdown]
# # TRACK

# %%
# !yolo track model=yolov8n.pt source="/content/input.mp4" conf=0.3, iou=0.5 show
# Out:
# WARNING ⚠️ 'conf=0.3,' does not require trailing comma ',', updating to 'conf=0.3'.
# ...
# 100% 6.23M/6.23M [00:00<00:00, 73.1MB/s]
# requirements: Ultralytics requirement ['lapx>=0.5.2'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 9.7 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 5.1s, installed 1 package: ['lapx>=0.5.2']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
# Ultralytics YOLOv8.0.171 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# video 1/1 (1/323) /content/input.mp4: 384x640 3 cars, 1 truck, 337.8ms
# video 1/1 (2/323) /content/input.mp4: 384x640 3 cars, 1 truck, 140.7ms
# video 1/1 (3/323) /content/input.mp4: 384x640 3 cars, 1 truck, 212.9ms
# video 1/1 (4/323) /content/input.mp4: 384x640 3 cars, 1 truck, 213.4ms
# ...

# %%
# save_path is the path to result of previous cell
save_path = "/content/runs/detect/predict/input.avi"
result_path = "/content/result.mp4"
os.system(f'ffmpeg -i {save_path} -vcodec libx264 {result_path}')
# Out:
# 0
